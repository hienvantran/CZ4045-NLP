# %% [markdown]
# <a href="https://colab.research.google.com/github/hienvantran/CZ4045-NLP/blob/main/Crawled-data/labbeling_with_pigeon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install pigeon-jupyter

# %%
#load csv from drive
to_label = pd.read_csv('/content/drive/MyDrive/unlabeled-test-name-1.csv') ### CHANGE HERE

# %%
#test 
#to_label = to_label.sample(5)

# %%
to_label
# Out:
#      sentiment      id                                              title  \
# 1162       TBA  pgx7ar                     Long live the labour shortages
# 387        TBA  q59t35  Central Bankers Are Spooked by Signs That Infl...
# 546        TBA  pyults         Wait . So the US government has no money ?
# 391        TBA  q5469v  Smaller packs, same price: curse of ‘shrinkfla...
# 897        TBA  pof7d2  Fund managers haven’t been this pessimistic on...
#
#       score                                       external_url  \
# 1162      1  https://amp.ft.com/content/cba9b4e5-db43-4a2b-...
# 387       1  https://www.bloomberg.com/news/articles/2021-1...
# 546       1  https://www.wrcbtv.com/story/44839445/us-gover...
# 391       1  https://www.theguardian.com/business/2021/oct/...
# 897       1  https://www.marketwatch.com/story/fund-manager...
#
#               author submitted_time
# 1162     sirboozebum     2021-09-03
# 387           fractx     2021-10-10
# ...

# %%
## use pigeon to annotate
from pigeon import annotate
annotations = annotate(
  to_label['title'],
  options=['positive', 'negative']
)
# Out:
# HTML(value='0 examples annotated, 6 examples left')
# ...
# Output()
# Annotation done.

# %%
labels = [i[1] for i in annotations]

# %%
to_label['sentiment'] = labels

# %%
to_label
# Out:
#      sentiment      id                                              title  \
# 1162  positive  pgx7ar                     Long live the labour shortages
# 387   negative  q59t35  Central Bankers Are Spooked by Signs That Infl...
# 546   negative  pyults         Wait . So the US government has no money ?
# 391   negative  q5469v  Smaller packs, same price: curse of ‘shrinkfla...
# 897   negative  pof7d2  Fund managers haven’t been this pessimistic on...
#
#       score                                       external_url  \
# 1162      1  https://amp.ft.com/content/cba9b4e5-db43-4a2b-...
# 387       1  https://www.bloomberg.com/news/articles/2021-1...
# 546       1  https://www.wrcbtv.com/story/44839445/us-gover...
# 391       1  https://www.theguardian.com/business/2021/oct/...
# 897       1  https://www.marketwatch.com/story/fund-manager...
#
#               author submitted_time
# 1162     sirboozebum     2021-09-03
# 387           fractx     2021-10-10
# ...

# %%
to_label.to_csv('/content/drive/MyDrive/unlabeled-test-name-1-labelled.csv') ### CHANGE HERE
