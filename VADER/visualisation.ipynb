# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
df = pd.read_csv('/Users/ryanphuay/Desktop/CZ4045-NLP/Crawled_data/8k-labelled-vader.csv')

# %%
df.shape
# Out:
# (8409, 11)

# %%
df.head()
# Out:
#   sentiment      id                                              title  score  \
# 0   neutral  q720ba  There Is Shadow Inflation Taking Place All Aro...      1
# 1  negative  q70zbp  Column: Unemployment benefits weren't what kep...      1
# 2  positive  q6zvh5  Lift the minimum wage and employment still ris...      1
# 3   neutral  q6zlua            When Environmental Regulations Backfire      1
# 4  positive  q6v19n  Pelosi says proposal to take debt ceiling auth...      1
#
#                                         external_url         author  \
# 0  https://www.nytimes.com/2021/10/10/upshot/shad...  RickRussellTX
# 1  https://finance.yahoo.com/news/column-unemploy...      amnesiac7
# 2           https://amp.abc.net.au/article/100531994    sirboozebum
# 3  https://www.city-journal.org/when-environmenta...    Dumbass1171
# 4  https://thehill.com/homenews/house/576354-pelo...     BlankVerse
#
#   submitted_time    neg    neu    pos  compound
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8409 entries, 0 to 8408
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sentiment       8409 non-null   object
#  1   id              8409 non-null   object
#  2   title           8409 non-null   object
#  3   score           8409 non-null   int64
#  4   external_url    8409 non-null   object
#  5   author          8409 non-null   object
#  6   submitted_time  8409 non-null   object
#  7   neg             8409 non-null   float64
#  8   neu             8409 non-null   float64
#  9   pos             8409 non-null   float64
#  10  compound        8409 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 722.8+ KB

# %%
df.drop_duplicates(subset=['title'],keep='first',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8409 entries, 0 to 8408
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sentiment       8409 non-null   object
#  1   id              8409 non-null   object
#  2   title           8409 non-null   object
#  3   score           8409 non-null   int64
#  4   external_url    8409 non-null   object
#  5   author          8409 non-null   object
#  6   submitted_time  8409 non-null   object
#  7   neg             8409 non-null   float64
#  8   neu             8409 non-null   float64
#  9   pos             8409 non-null   float64
#  10  compound        8409 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 788.3+ KB

# %%
text = " ".join([x for x in df.title])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## for neutral

text = " ".join([x for x in df.title[df.sentiment=='neutral']])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## for positive

text = " ".join([x for x in df.title[df.sentiment=='positive']])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## for negative

text = " ".join([x for x in df.title[df.sentiment=='negative']])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
sns.countplot(x=df["sentiment"])
# Out:
# <AxesSubplot:xlabel='sentiment', ylabel='count'>

# %%
df['sentiment'].value_counts()
# Out:
# negative    3050
# neutral     2846
# positive    2513
# Name: sentiment, dtype: int64
